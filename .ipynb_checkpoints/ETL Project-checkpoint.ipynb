# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
legislators_file = "Resources/legislators-current-terms.csv"
legislators_df = pd.read_csv(legislators_file)
legislators_df.head()
# Out:
#   address bioguide caucus chamber  class contact_form  district         end  \
# 0     NaN  B000944    NaN     NaN    NaN          NaN      13.0  1995-01-03
# 1     NaN  B000944    NaN     NaN    NaN          NaN      13.0  1997-01-03
# 2     NaN  B000944    NaN     NaN    NaN          NaN      13.0  1999-01-03
# 3     NaN  B000944    NaN     NaN    NaN          NaN      13.0  2001-01-03
# 4     NaN  B000944    NaN     NaN    NaN          NaN      13.0  2003-01-03
#
#    fax last  ... party_affiliations phone relation rss_url       start state  \
# 0  NaN  NaN  ...                NaN   NaN      NaN     NaN  1993-01-05    OH
# 1  NaN  NaN  ...                NaN   NaN      NaN     NaN  1995-01-04    OH
# 2  NaN  NaN  ...                NaN   NaN      NaN     NaN  1997-01-07    OH
# 3  NaN  NaN  ...                NaN   NaN      NaN     NaN  1999-01-06    OH
# 4  NaN  NaN  ...                NaN   NaN      NaN     NaN  2001-01-03    OH
#
#   state_rank title type  url
# 0        NaN   NaN  rep  NaN
# 1        NaN   NaN  rep  NaN
# 2        NaN   NaN  rep  NaN
# 3        NaN   NaN  rep  NaN
# 4        NaN   NaN  rep  NaN
#
# [5 rows x 23 columns]

# %%
no_health_ins_file = "Resources/Population_Without_Health_Insurance_Coverage_State_2013-2015.csv"
no_health_ins_df = pd.read_csv(no_health_ins_file)
no_health_ins_df.head()
# Out:
#            State Medicaid Expansion State?        Yes (Y) or No (N)1  \
# 0  United States                                                NaN
# 1        Alabama                                                  N
# 2         Alaska                                                  N
# 3        Arizona                                                  Y
# 4       Arkansas                                                  Y
#
#   2013 Uninsured - Number in thousands  \
# 0                               45,181
# 1                                  645
# 2                                  132
# 3                                1,118
# 4                                  465
#
#    2013 Uninsured - Number - Margin of Error2 (±)    2013 Uninsured - Percent  \
# 0                                               200                      14.5
# 1                                                17                      13.6
# 2                                                 7                      18.5
# 3                                                24                      17.1
# 4                                                14                      16.0
#
#    2013 Uninsured - Percent - Margin of Error2 (±)   2014 Uninsured - Number  \
# 0                                                0.1                  36,670
# 1                                                0.4                     579
# 2                                                1.0                     122
# 3                                                0.4                     903
# 4                                                0.5                     343
#
#    2014 Uninsured - Number - Margin of Error2 (±)   2014 Uninsured - Percent  \
# 0                                              190                      11.7
# 1                                               17                      12.1
# 2                                                6                      17.2
# 3                                               18                      13.6
# 4                                               13                      11.8
#
#    2014 Uninsured - Percent - Margin of Error2 (±)   ...  \
# 0                                               0.1  ...
# 1                                               0.4  ...
# 2                                               0.9  ...
# 3                                               0.3  ...
# 4                                               0.4  ...
#
#   2015 Uninsured - Percent  2015 Uninsured - Percent - Margin of Error2 (±)   \
# 0                      9.4                                               0.1
# 1                     10.1                                               0.3
# 2                     14.9                                               0.7
# 3                     10.8                                               0.3
# 4                      9.5                                               0.4
#
#    Difference in Uninsured (2015 less 2014) - Number  \
# 0                                            *-6,913
# 1                                               *-95
# 2                                               *-16
# 3                                              *-175
# 4                                               *-66
#
#    Difference in Uninsured (2015 less 2014) - Number - Margin of Error2 (±)   \
# 0                                                261
# 1                                                 23
# 2                                                  8
# 3                                                 28
# 4                                                 18
#
#   Difference in Uninsured (2015 less 2014) - Percent  \
# 0                                              *-2.3
# 1                                              *-2.0
# 2                                              *-2.3
# 3                                              *-2.8
# 4                                              *-2.3
#
#    Difference in Uninsured (2015 less 2014) - Percent - Margin of Error2 (±)   \
# 0                                                0.1
# 1                                                0.5
# 2                                                1.1
# 3                                                0.4
# 4                                                0.6
#
#   Difference in Uninsured (2015 less 2013) - Number  \
# 0                                          *-15,423
# 1                                             *-161
# 2                                              *-26
# 3                                             *-390
# 4                                             *-187
#
#    Difference in Uninsured (2015 less 2013) - Number - Margin of Error2 (±)   \
# 0                                                269
# 1                                                 23
# 2                                                  9
# 3                                                 32
# 4                                                 18
#
#   Difference in Uninsured (2015 less 2013) - Percent  \
# 0                                              *-5.1
# 1                                              *-3.4
# 2                                              *-3.7
# 3                                              *-6.3
# 4                                              *-6.5
#
#    Difference in Uninsured (2015 less 2013)- Percent - Margin of Error2 (±)
# 0                                                0.1
# 1                                                0.5
# 2                                                1.2
# 3                                                0.5
# 4                                                0.6
#
# [5 rows x 22 columns]
